# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_excel("Student-Employability-Datasets.xlsx")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2982 entries, 0 to 2981
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Name of Student             2982 non-null   object
#  1   GENERAL APPEARANCE          2982 non-null   int64
#  2   MANNER OF SPEAKING          2982 non-null   int64
#  3   PHYSICAL CONDITION          2982 non-null   int64
#  4   MENTAL ALERTNESS            2982 non-null   int64
#  5   SELF-CONFIDENCE             2982 non-null   int64
#  6   ABILITY TO PRESENT IDEAS    2982 non-null   int64
#  7   COMMUNICATION SKILLS        2982 non-null   int64
#  8   Student Performance Rating  2982 non-null   int64
#  9   CLASS                       2982 non-null   object
# dtypes: int64(8), object(2)
# memory usage: 233.1+ KB

# %%
total =  df.drop(columns = ['Name of Student', 'CLASS'])
# Out:
# GENERAL APPEARANCE            12664
# MANNER OF SPEAKING            11584
# PHYSICAL CONDITION            11845
# MENTAL ALERTNESS              11817
# SELF-CONFIDENCE               11662
# ABILITY TO PRESENT IDEAS      11373
# COMMUNICATION SKILLS          10513
# Student Performance Rating    13749
# dtype: int64

# %%
plt.figure(figsize = (12,6))

sns.barplot(data = total.sum())
# Out:
# <AxesSubplot:>

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

x = df.drop(columns = ['CLASS', 'Name of Student'])
y = df['CLASS']

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2)

model = DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %%
pred = model.predict(x_test)
pred
# Out:
# array(['LessEmployable', 'Employable', 'Employable', 'Employable',
#        'Employable', 'LessEmployable', 'LessEmployable', 'Employable',
#        'LessEmployable', 'LessEmployable', 'LessEmployable', 'Employable',
#        'Employable', 'Employable', 'LessEmployable', 'Employable',
#        'LessEmployable', 'LessEmployable', 'Employable', 'LessEmployable',
#        'Employable', 'Employable', 'LessEmployable', 'LessEmployable',
#        'Employable', 'Employable', 'LessEmployable', 'Employable',
#        'LessEmployable', 'LessEmployable', 'Employable', 'LessEmployable',
#        'LessEmployable', 'Employable', 'Employable', 'Employable',
#        'Employable', 'LessEmployable', 'Employable', 'Employable',
#        'Employable', 'Employable', 'Employable', 'LessEmployable',
#        'LessEmployable', 'Employable', 'LessEmployable', 'LessEmployable',
#        'Employable', 'LessEmployable', 'LessEmployable', 'Employable',
# ...

# %%
model.predict_proba(x_test)
# Out:
# array([[0.45454545, 0.54545455],
#        [0.65116279, 0.34883721],
#        [0.74509804, 0.25490196],
#        ...,
#        [1.        , 0.        ],
#        [0.        , 1.        ],
#        [0.        , 1.        ]])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, pred)
# Out:
# 0.8994974874371859

# %%
from sklearn import tree

fig = plt.figure(figsize =(50,40))
_ = tree.plot_tree(model, filled=True, fontsize = 12)

# %%
x
# Out:
#       GENERAL APPEARANCE  MANNER OF SPEAKING  PHYSICAL CONDITION  \
# 0                      4                   5                   4
# 1                      4                   4                   4
# 2                      4                   3                   3
# 3                      3                   3                   3
# 4                      4                   4                   3
# ...                  ...                 ...                 ...
# 2977                   4                   3                   3
# 2978                   3                   4                   4
# 2979                   4                   5                   4
# 2980                   4                   4                   4
# 2981                   4                   4                   4
#
#       MENTAL ALERTNESS  SELF-CONFIDENCE  ABILITY TO PRESENT IDEAS  \
# 0                    5                5                         5
# ...

# %%
cols = x.columns

arr = []

print("Enter the scores")

for col in cols:
    score = int(input(f'\t{col}: '))
    arr.append(score)
    
prediction = model.predict([arr])
prediction
# Out:
# Enter the scores
